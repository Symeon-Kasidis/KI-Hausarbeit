# %%
#import block
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os
import matplotlib.pyplot as plt

#define all variables here to use later 
#set to cuda if you have an nvidia GPU. AMD GPUS (ROCm on linux but only for 7000 series and up) are not properly supported so just let it to cpu (will take longer to train than gpu)
device = torch.device("cpu") 
# default values thatmake sure i dont have undefined values. They will be overwritten during training
#value for one-hot encode. Here it is 2 because that what the docu says binary classification
label_dim = 2
# Dimension of the random noise vector
noise_dim = 100
# Define loss function and optimizers
criterion = nn.BCELoss()  # Binary Cross-Entropy Loss
#trainings cycles
epochs = 50
lr = 0.0002
beta1 = 0.5
latent_dim = 100

# %%
class RatioDataset(Dataset):
    def __init__(self, image_dir, num_dogs, num_cats, transform=None):
        self.transform = transform
        self.image_paths = []
        self.labels = []

        # Load dog images
        dog_dir = os.path.join(image_dir, "Dog")
        dog_images = os.listdir(dog_dir)[:num_dogs]
        self.image_paths.extend([os.path.join(dog_dir, img) for img in dog_images])
        self.labels.extend([1] * len(dog_images))  # 1 for dogs

        # Load cat images
        cat_dir = os.path.join(image_dir, "Cat")
        cat_images = os.listdir(cat_dir)[:num_cats]
        self.image_paths.extend([os.path.join(cat_dir, img) for img in cat_images])
        self.labels.extend([0] * len(cat_images))  # 0 for cats

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image = Image.open(self.image_paths[idx]).convert("RGB")
        label = self.labels[idx]
        if self.transform:
            image = self.transform(image)
        return image, label

# %%
transform = transforms.Compose([
    transforms.Resize((128, 128)),       # Resize to 128x128
    transforms.ToTensor(),               # Convert to tensor
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))  # Normalize to [-1, 1]
])

# %%
image_dir = "archive/PetImages"  # Replace with your dataset's path

# Example: 100 dogs and 100 cats
dataset = RatioDataset(image_dir=image_dir, num_dogs=10, num_cats=3, transform=transform)
data_loader = DataLoader(dataset, batch_size=64, shuffle=True)

# %%
class Discriminator(nn.Module):
    def __init__(self, label_dim):
        super(Discriminator, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(3*128*128 + label_dim, 1024),  # Input is the concatenated image and label
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(1024, 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),  # Output is a single scalar (real or fake)
            nn.Sigmoid()  # Sigmoid activation to output a probability
        )

    def forward(self, img, labels):
        x = torch.cat([img.view(img.size(0), -1), labels], dim=1)  # Concatenate image and label
        return self.fc(x)  # Output a probability (real or fake)

# %%
class Generator(nn.Module):
    def __init__(self, noise_dim, label_dim):
        super(Generator, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(noise_dim + label_dim, 256),
            nn.ReLU(True),
            nn.Linear(256, 512),
            nn.ReLU(True),
            nn.Linear(512, 1024),
            nn.ReLU(True),
            nn.Linear(1024, 3*128*128),  # Output size for a 128x128 image (3 channels for RGB)
            nn.Tanh()  # Normalize to the range [-1, 1] (for image data)
        )

    def forward(self, z, labels):
        #labels = nn.functional.one_hot(labels, num_classes=label_dim).float()
        x = torch.cat([z, labels], dim=1)  # Concatenate noise vector with label vector
        return self.fc(x).view(-1, 3, 128, 128)  # Reshape to image size (3 channels)

# %%
import matplotlib.pyplot as plt
def generate_images(generator, label, num_images=6):
    generator.eval()
    
    # Generate noise and labels
    noise = torch.randn(num_images, noise_dim, device=device)
    one_hot_label = nn.functional.one_hot(torch.tensor([label] * num_images), num_classes=label_dim).float().to(device)
    fake_imgs = generator(noise, one_hot_label).detach().cpu()
    # Determine grid size (e.g., 2 rows and 3 columns for 6 images)
    grid_rows = 2
    grid_cols = 3
    
    # Set up the grid for plotting
    fig, axes = plt.subplots(grid_rows, grid_cols, figsize=(10, 7))
    axes = axes.flatten()  # Flatten the grid to make indexing easier

    # Plot each image on the grid
    for i in range(num_images):
        img = (fake_imgs[i] + 1) / 2  # Rescale to [0, 1]
        img = img.permute(1, 2, 0).numpy()  # Rearrange to (H, W, C) for plotting
        axes[i].imshow(img)
        axes[i].axis("off")
    
    # Remove any unused axes if the grid is larger than num_images
    for j in range(num_images, len(axes)):
        axes[j].axis("off")

    # Show the grid
    plt.tight_layout()
    plt.show()

# %%
# Define the number of epochs
epochs = 150  # Adjust as needed

generator = Generator(noise_dim, label_dim)
discriminator = Discriminator(label_dim)
optimizer_g = optim.Adam(generator.parameters(), lr=0.0002, betas=(0.5, 0.999))
optimizer_d = optim.Adam(discriminator.parameters(), lr=0.0002, betas=(0.5, 0.999))

# Training loop
for epoch in range(epochs):
    for real_imgs, labels in data_loader:
        batch_size = real_imgs.size(0)
        real_imgs, labels = real_imgs.to(device), labels.to(device)

        # One-hot encode labels
        one_hot_labels = nn.functional.one_hot(labels, num_classes=label_dim).float().to(device)

        # Train Discriminator
        noise = torch.randn(batch_size, noise_dim, device=device)
        fake_imgs = generator(noise, one_hot_labels)
        real_preds = discriminator(real_imgs, one_hot_labels)
        fake_preds = discriminator(fake_imgs.detach(), one_hot_labels)
        loss_d = criterion(real_preds, torch.ones_like(real_preds)) + \
                 criterion(fake_preds, torch.zeros_like(fake_preds))

        optimizer_d.zero_grad()
        loss_d.backward()
        optimizer_d.step()

        # Train Generator
        fake_preds = discriminator(fake_imgs, one_hot_labels)
        loss_g = criterion(fake_preds, torch.ones_like(fake_preds))

        optimizer_g.zero_grad()
        loss_g.backward()
        optimizer_g.step()

    print(f"Epoch [{epoch+1}/{epochs}] Loss D: {loss_d:.4f}, Loss G: {loss_g:.4f}")
    # if epoch % 10 == 0:
        # generate_images(generator, label=0, num_images=2)
        # generate_images(generator, label=1, num_images=2)
# Out:
# Epoch [1/150] Loss D: 1.3799, Loss G: 0.7002
# Epoch [2/150] Loss D: 0.9297, Loss G: 0.7052
# Epoch [3/150] Loss D: 0.7422, Loss G: 0.7257
# Epoch [4/150] Loss D: 0.7009, Loss G: 0.7507
# Epoch [5/150] Loss D: 0.6760, Loss G: 0.7747
# Epoch [6/150] Loss D: 0.6702, Loss G: 0.8052
# Epoch [7/150] Loss D: 0.6712, Loss G: 0.8370
# Epoch [8/150] Loss D: 0.6766, Loss G: 0.8687
# Epoch [9/150] Loss D: 0.6812, Loss G: 0.8625
# Epoch [10/150] Loss D: 0.7309, Loss G: 0.8692
# Epoch [11/150] Loss D: 0.7099, Loss G: 0.8838
# Epoch [12/150] Loss D: 0.6895, Loss G: 0.8704
# Epoch [13/150] Loss D: 0.7124, Loss G: 0.8275
# Epoch [14/150] Loss D: 0.7650, Loss G: 0.7779
# Epoch [15/150] Loss D: 0.7849, Loss G: 0.7341
# Epoch [16/150] Loss D: 0.7706, Loss G: 0.7482
# Epoch [17/150] Loss D: 0.6964, Loss G: 0.8009
# Epoch [18/150] Loss D: 0.6265, Loss G: 0.8812
# Epoch [19/150] Loss D: 0.5829, Loss G: 0.9471
# Epoch [20/150] Loss D: 0.5575, Loss G: 1.0023
# Epoch [21/150] Loss D: 0.5274, Loss G: 1.0890
# Epoch [22/150] Loss D: 0.5218, Loss G: 1.1224
# Epoch [23/150] Loss D: 0.6236, Loss G: 0.9809
# Epoch [24/150] Loss D: 0.7938, Loss G: 0.7769
# Epoch [25/150] Loss D: 0.7497, Loss G: 0.8799
# Epoch [26/150] Loss D: 0.5972, Loss G: 1.2908
# Epoch [27/150] Loss D: 0.4411, Loss G: 1.7068
# Epoch [28/150] Loss D: 0.4665, Loss G: 1.3499
# Epoch [29/150] Loss D: 0.6570, Loss G: 0.8490
# Epoch [30/150] Loss D: 0.6353, Loss G: 0.9385
# Epoch [31/150] Loss D: 0.6176, Loss G: 0.9858
# Epoch [32/150] Loss D: 0.6267, Loss G: 0.9425
# Epoch [33/150] Loss D: 0.5003, Loss G: 1.3199
# Epoch [34/150] Loss D: 0.4898, Loss G: 1.2947
# Epoch [35/150] Loss D: 0.4453, Loss G: 1.3416
# Epoch [36/150] Loss D: 0.5193, Loss G: 1.2067
# Epoch [37/150] Loss D: 0.5909, Loss G: 1.1094
# Epoch [38/150] Loss D: 0.5437, Loss G: 1.3047
# Epoch [39/150] Loss D: 0.6033, Loss G: 1.0705
# Epoch [40/150] Loss D: 3.9987, Loss G: 0.9011
# Epoch [41/150] Loss D: 0.6960, Loss G: 0.8256
# Epoch [42/150] Loss D: 2.4541, Loss G: 0.5063
# Epoch [43/150] Loss D: 1.7459, Loss G: 0.3794
# Epoch [44/150] Loss D: 1.7821, Loss G: 0.4141
# Epoch [45/150] Loss D: 1.5717, Loss G: 0.5237
# Epoch [46/150] Loss D: 1.2309, Loss G: 0.7013
# Epoch [47/150] Loss D: 0.8486, Loss G: 0.8921
# Epoch [48/150] Loss D: 0.6298, Loss G: 1.0505
# Epoch [49/150] Loss D: 0.5871, Loss G: 0.9795
# Epoch [50/150] Loss D: 0.5856, Loss G: 0.9735
# Epoch [51/150] Loss D: 0.6727, Loss G: 0.8195
# Epoch [52/150] Loss D: 0.8465, Loss G: 0.7179
# Epoch [53/150] Loss D: 1.0345, Loss G: 0.4375
# Epoch [54/150] Loss D: 1.4017, Loss G: 0.4387
# Epoch [55/150] Loss D: 1.3301, Loss G: 0.5878
# Epoch [56/150] Loss D: 1.4313, Loss G: 0.3398
# Epoch [57/150] Loss D: 1.5428, Loss G: 0.4147
# Epoch [58/150] Loss D: 1.3783, Loss G: 0.6175
# Epoch [59/150] Loss D: 1.0025, Loss G: 0.8744
# Epoch [60/150] Loss D: 0.9096, Loss G: 0.8256
# Epoch [61/150] Loss D: 0.7782, Loss G: 1.0213
# Epoch [62/150] Loss D: 0.6426, Loss G: 1.1892
# Epoch [63/150] Loss D: 0.6177, Loss G: 1.0307
# Epoch [64/150] Loss D: 0.6299, Loss G: 1.0500
# Epoch [65/150] Loss D: 0.6058, Loss G: 1.0565
# Epoch [66/150] Loss D: 0.6300, Loss G: 0.9029
# Epoch [67/150] Loss D: 0.7055, Loss G: 0.8503
# Epoch [68/150] Loss D: 0.7219, Loss G: 0.8657
# Epoch [69/150] Loss D: 0.7950, Loss G: 0.6373
# Epoch [70/150] Loss D: 0.8828, Loss G: 0.6361
# Epoch [71/150] Loss D: 0.8729, Loss G: 0.6813
# Epoch [72/150] Loss D: 0.7853, Loss G: 0.7529
# Epoch [73/150] Loss D: 0.8131, Loss G: 0.6734
# Epoch [74/150] Loss D: 0.8181, Loss G: 0.6938
# Epoch [75/150] Loss D: 0.7582, Loss G: 0.7724
# Epoch [76/150] Loss D: 0.6956, Loss G: 0.8338
# Epoch [77/150] Loss D: 0.6454, Loss G: 0.8732
# Epoch [78/150] Loss D: 0.5731, Loss G: 0.9605
# Epoch [79/150] Loss D: 0.5358, Loss G: 1.0035
# Epoch [80/150] Loss D: 0.4980, Loss G: 1.0552
# Epoch [81/150] Loss D: 0.4819, Loss G: 1.0725
# Epoch [82/150] Loss D: 0.4704, Loss G: 1.0862
# Epoch [83/150] Loss D: 0.4590, Loss G: 1.1042
# Epoch [84/150] Loss D: 0.4727, Loss G: 1.0848
# Epoch [85/150] Loss D: 0.4922, Loss G: 1.0522
# Epoch [86/150] Loss D: 0.5800, Loss G: 0.9826
# Epoch [87/150] Loss D: 0.8585, Loss G: 0.9004
# Epoch [88/150] Loss D: 1.2108, Loss G: 0.8274
# Epoch [89/150] Loss D: 1.3113, Loss G: 0.8728
# Epoch [90/150] Loss D: 1.0129, Loss G: 0.9980
# Epoch [91/150] Loss D: 0.7195, Loss G: 1.1076
# Epoch [92/150] Loss D: 0.6022, Loss G: 1.2609
# Epoch [93/150] Loss D: 0.5481, Loss G: 1.3248
# Epoch [94/150] Loss D: 0.8691, Loss G: 0.4424
# Epoch [95/150] Loss D: 2.9788, Loss G: 0.3001
# Epoch [96/150] Loss D: 2.9481, Loss G: 1.0653
# Epoch [97/150] Loss D: 1.3099, Loss G: 1.7240
# Epoch [98/150] Loss D: 0.5079, Loss G: 1.9749
# Epoch [99/150] Loss D: 0.8688, Loss G: 0.9992
# Epoch [100/150] Loss D: 0.7843, Loss G: 0.7297
# Epoch [101/150] Loss D: 0.9858, Loss G: 0.4816
# Epoch [102/150] Loss D: 1.0697, Loss G: 0.4766
# Epoch [103/150] Loss D: 1.0942, Loss G: 0.5224
# Epoch [104/150] Loss D: 1.0078, Loss G: 0.6130
# Epoch [105/150] Loss D: 0.8834, Loss G: 0.7876
# Epoch [106/150] Loss D: 0.6905, Loss G: 0.9539
# Epoch [107/150] Loss D: 0.6961, Loss G: 0.8419
# Epoch [108/150] Loss D: 0.6387, Loss G: 0.8832
# Epoch [109/150] Loss D: 0.6043, Loss G: 1.0359
# Epoch [110/150] Loss D: 0.5040, Loss G: 1.2316
# Epoch [111/150] Loss D: 0.4672, Loss G: 1.1996
# Epoch [112/150] Loss D: 0.4697, Loss G: 1.1039
# Epoch [113/150] Loss D: 0.5116, Loss G: 1.0439
# Epoch [114/150] Loss D: 0.5404, Loss G: 1.0247
# Epoch [115/150] Loss D: 0.6082, Loss G: 0.8606
# Epoch [116/150] Loss D: 0.6749, Loss G: 0.8272
# Epoch [117/150] Loss D: 0.6985, Loss G: 0.8417
# Epoch [118/150] Loss D: 0.6396, Loss G: 0.8702
# Epoch [119/150] Loss D: 0.5894, Loss G: 0.9307
# Epoch [120/150] Loss D: 0.5601, Loss G: 1.0191
# Epoch [121/150] Loss D: 0.5489, Loss G: 0.9552
# Epoch [122/150] Loss D: 0.5422, Loss G: 0.9859
# Epoch [123/150] Loss D: 0.5251, Loss G: 1.0294
# Epoch [124/150] Loss D: 0.5358, Loss G: 0.9556
# Epoch [125/150] Loss D: 0.5407, Loss G: 0.9826
# Epoch [126/150] Loss D: 0.5492, Loss G: 0.9656
# Epoch [127/150] Loss D: 0.5305, Loss G: 1.0025
# Epoch [128/150] Loss D: 0.5337, Loss G: 0.9738
# Epoch [129/150] Loss D: 0.5343, Loss G: 1.0558
# Epoch [130/150] Loss D: 0.5354, Loss G: 0.8607
# Epoch [131/150] Loss D: 0.6308, Loss G: 0.9478
# Epoch [132/150] Loss D: 0.6003, Loss G: 1.1311
# Epoch [133/150] Loss D: 0.5215, Loss G: 1.0715
# Epoch [134/150] Loss D: 0.4885, Loss G: 1.1090
# Epoch [135/150] Loss D: 0.5791, Loss G: 0.6989
# Epoch [136/150] Loss D: 0.7381, Loss G: 0.7250
# Epoch [137/150] Loss D: 0.7651, Loss G: 0.8574
# Epoch [138/150] Loss D: 0.6253, Loss G: 1.0938
# Epoch [139/150] Loss D: 0.6663, Loss G: 0.9485
# Epoch [140/150] Loss D: 0.5473, Loss G: 1.0269
# Epoch [141/150] Loss D: 0.5005, Loss G: 1.1582
# Epoch [142/150] Loss D: 0.7358, Loss G: 0.6857
# Epoch [143/150] Loss D: 0.7607, Loss G: 0.6162
# Epoch [144/150] Loss D: 0.8098, Loss G: 0.6800
# Epoch [145/150] Loss D: 0.7552, Loss G: 0.8002
# Epoch [146/150] Loss D: 0.6419, Loss G: 0.9796
# Epoch [147/150] Loss D: 0.4982, Loss G: 1.1588
# Epoch [148/150] Loss D: 0.5403, Loss G: 0.9002
# Epoch [149/150] Loss D: 0.5474, Loss G: 0.8872
# Epoch [150/150] Loss D: 0.5605, Loss G: 0.9963

# %%
print("Dog Pictures")
# Generate 5 dog images (label=1)
num_images = 6
generate_images(generator, label=1, num_images=6)
print("Cat Pictures")
# Generate 5 cat images (label=0)
generate_images(generator, label=0, num_images=6)
# Out:
# Dog Pictures
# Cat Pictures
